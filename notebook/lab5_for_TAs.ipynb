# %% [markdown]
# # Lab Weeks 5

# %% [markdown]
# ### This is considered for week 5 labs,
# ### However, it may take more than 1 week
# ####

# %%
# importing modules 
import cv2     # open cv 2 package
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### part 1: utils_2023.ipynb review
# - Open and review functions exist in that notebook
# - Describe their applications to students
# - Review the test results generated by that notebook

# %% [markdown]
# ### part 2: Median Filters
# Two images below have been conducted with salt 'n pepper, dot noise with different intensity
# 1. noisy_car5.jpg
# 2. noisy_car15.jpg
#
# Then,
# - use open cv's medianBlur function,
# - the 2nd parameter, ksize, is the Median window's size
# - filter each image with ksize= 3 , 5 , 15
# - see the results, discuss the results

# %%
img = cv2.imread('..\\noisy_car5.jpg')

print(img.shape)
filteredImg = cv2.medianBlur(img, ksize=3)

cv2.imshow('Original image', img)
cv2.imshow('Filtered image', filteredImg)

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# (1080, 1920, 3)

# %% [markdown]
# ### part 3: Fourier Transform
# ####
# #### run fft1.ipynb,
# #### see the power spectral density and phase of Fourier transform of the image
# ### see the results of fftshift and log scale visualization
# #### you may try images below too
#
# 1. img = cv.imread('high_spat_freq.bmp', 0)
# 2. img = cv.imread('low_spat_freq.bmp', 0)
# 3. img = cv.imread('vertical_texture.bmp', 0)
# 4. img = cv.imread('diag_texture.bmp', 0)
# 5. img = cv.imread('IMG_plain.JPG', 0)
# 6. img = cv.imread('hor_texture.jpg ', 0)
#
# #### I. Use a gray level image
# #### II. Develop an FFT function that would be able to show you the FFT results: PSD and Phase
# #### III. Compute the image power in the spatial domain and FFT domain.
# ####      To do that, you need a routine or instruction to compute the power of a complex matrix
# #### IV. Compute the sum of all the pixels of your image and compare it with index [0,0] of the PSD matrix before shift
# ### Discuss it

# %% [markdown]
# ## part 4: Filtering in Fourier Domain
# #### run fft_filter2.ipynb
# #### use the FFT domain filters available in utils_2023 notebook
# #### available filters:
# #### - ideal lowpass, highpass, bandpass, band eject
# #### - Gaussian lowpass and highpass
# #### - Butterworth lowpass, highpass, bandpass, bandreject
# #### ....
# 1. Compare the ideal lowpass and Gaussian lowpass filters, resulting images should be reviewed
# 2. Compare Gaussian, ideal, and Butterworth high pass filters
# 3. Compare Butterworth and ideal bandpass filters
# 4. Apply Butterworth bandpass filter, change thefilter order parameter and see the differences

# %% [markdown]
# ### For Students:

# %% [markdown]
# 1. Develop a program to apply FFT domain filtering on your image
# 2. Procedure:
# - read the image
# - compute its FFT
# - apply fft shift
# - get the absolute value/PSD and phase of the FFT
# - design your filter
# - apply your filter on the absolute value matrix
# - -- element-wise multiplication
# - make the complex FFT matrix
# - apply inverse shift
# - apply inverse FFT
# - show the resulting filtered image

# %% [markdown]
# #### now you may use fig and subplot and show everything here

# %%
# create figure
fig = plt.figure(figsize=(10,10))

# %% [markdown]
# ##### the end of lab 5 notebook ...

# %%
cv2.waitKey()
cv2.destroyAllWindows()
